# %%
import requests
import json

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(occupation_fields):
    search_params = {
        'occupation-field': list(occupation_fields), 
        'limit': 0
    }
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(occupation_fields):
    search_params = {
        'occupation-field': list(occupation_fields),
        'limit': 100
    }
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:   
        print(f"{hit['headline']}, {hit['employer']['name']}")


occupation_fields = ("E7hm_BLq_fqZ", "GazW_2TU_kJw", "apaJ_2ja_LuF")
example_search_return_number_of_hits(occupation_fields)
example_search_loop_through_hits(occupation_fields)
# Out:
# Number of hits = 6696
# Vakthavande befäl till VO Häktet Helsingborg (vikariat), Kriminalvården
# Säkerhetshandläggare med ansvar för brand till anstalten Kumla, Kriminalvården
# Vakthavande befäl till VO Häktet Helsingborg, Kriminalvården
# Handläggare Verkställighets planerare (VSP) Nya Anstalten Lindåsa , Tollarp, Kriminalvården
# Brandman RIB Skänninge, Mjölby kommun
# Väktare till Stenungsund, Addici Security AB
# Vi söker brandvakt till Örebro., Optima Bemanning AB
# Vi söker brandvakt till Örebro., Optima Bemanning AB
# Säkerhetspecialist, RISE Research Institutes of Sweden AB
# Vi söker en Arbetsledare till Stockholm, Avarn Security AB
# Säkerhetssamordnare inriktning Civil beredskap, Trafikverket
# Avarn Security söker arbetsledare på heltid, Avarn Security AB
# Lotsoperatör– tidsbegränsad anställning vid behov, Sjöfartsverket
# Vi söker dig som vill ha fart i vardagen!, Simplex Bemanning AB
# Arbetsmiljöspecialist – NCC Building Avdelning Väst (vikariat) , NCC AB
# Underrättelsehandläggare, Kriminalvården
# Förundersökningsledare till Västberga , Polismyndigheten
# Säkerhetsspecialist – Fysisk säkerhet & säkerhetsskydd, Devotum AB
# Senior arbetsmiljö- och säkerhetsrådgivare - Umeå, Experis AB
# Kriminalvårdare till Häktet Kronoberg, Stockholm, Kriminalvården
# Informationssäkerhetsspecialist, Statens Fastighetsverk
# Brinner du för långsiktig hållbar verksamhet? Sök Miljösamordnare hos oss!, Bae Systems Hägglunds AB
# Förundersökningsledare till Globen och Farsta, Polismyndigheten
# Ingenjör eller inspektör till förebyggandeavdelningen, RÄDDNINGSTJÄNSTEN MÄLARDALEN
# Vakthavande befäl till anstalt/häkte Högsbo  , Kriminalvården
# Säkerhetshandläggare, Försvarsmakten
# Säkerhetssamordnare till Danderyds kommun , Danderyds kommun
# Operatör/koordinator- felavhjälpning järnväg, Trafikverket
# Skaraborgs tingsrätt söker serviceinriktad vikarierande expeditions- och or, Sveriges Domstolar
# Utbildade ordningsvakter till Securitas Kungälv - Heltid, Securitas AB
# Gruppledare -Natt, Securitas AB
# Strateg med inriktning informationssäkerhet, Stockholms kommun
# Ordningsvakter - heltid och deltid Stockholm, Securitas AB
# Arrestantvakt till Katrineholm, Polismyndigheten
# Värdetransportör Karlstad, Loomis Sverige AB
# Expert inom narkotika och narkotikahundverksamhet , Kriminalvården
# Väktare  Inriktning Handel Securitas Stockholm, Securitas AB
# Senior konsult inom GOP, TSS och TSB till SYSTRA, SYSTRA AB
# Säkerhetsgranskare till SYSTRA AB, SYSTRA AB
# Säkerhetsgranskare till SYSTRA AB, SYSTRA AB
# Säkerhetsgranskare till SYSTRA AB, SYSTRA AB
# Säkerhetsgranskare till SYSTRA AB, SYSTRA AB
# Kommunpolis till lokalpolisområde Varberg, Polismyndigheten
# HSEQ Coordinator, Keller Grundläggning AB
# Säkerhetssamordnare med inriktning mot säkerhetsskydd, ÖRNSKÖLDSVIKS KOMMUN
# Avarn Security söker medarbetare till vår parkeringsavdelning, Avarn Security AB
# Biträdande säkerhetsskyddschef, Ellevio AB
# Brandman till Uppsala Brandförsvar, Uppsala kommun
# Brandman (sommarvikarie) till Uppsala Brandförsvar, Uppsala kommun
# Gruppledare dagtid - Karlstad, Securitas AB
# Ingenjör inriktning Cybersäkerhet | Cytiva | Distans, Lernia Bemanning AB
# Väktarutbildning Luleå / Boden, Tempest Security Sverige AB
# Brandinspektör, Lycksele kommun
# Säkerhetskoordinator, Sollentuna kommun
# Stationär väktare behovsanställning - Göteborg, Securitas AB
# Nu söker vi Badmästare till Valhallabadet!, Got Event AB
# Brandgruppen Nord etableras i Norrbotten, vi söker nu brandskyddstekniker!, Professionals Nord Luleå AB
# Brandgruppen Nord etableras i Norrbotten, vi söker nu brandskyddstekniker!, Professionals Nord Luleå AB
# Brandgruppen Nord etableras i Norrbotten, vi söker nu brandskyddstekniker!, Professionals Nord Luleå AB
# Kommunpolis till lokalpolisområde Botkyrka , Polismyndigheten
# Besiktningstekniker (certifierad eller tidigare varit)  södra Stockholm, ToppTalang Nordic AB
# Bad- och simhallspersonal, Hultsfreds kommun
# Arbetsmiljö- ingenjör/strateg/samordnare/tekniker, Tarkett AB
# Parkeringsvakt till parkeringsenheten, Norrköpings kommun
# Besiktningstekniker till Bilprovningen Landvetter/Borås, Svensk Autorekrytering AB
# Stationschef till Carspect Hudiksvall, Carspect AB
# Brandskyddsledare /Väktare till Securitas, Securitas AB
# Besiktningstekniker, The We Select Company AB
# Falu tingsrätt söker ordningsvakt med admin. uppgifter, en el. flera, Sveriges Domstolar
# Besiktningstekniker, The We Select Company AB
# Kriminalvårdare  Häktet Göteborg  , Kriminalvården
# Säkerhets-/riskstrateg inriktning säkerhetsskydd, Trafikverket
# Sakkunnig inom säkerhets- och beredskapsarbete till utbildningskontoret, Norrköpings kommun
# Arbetsmiljöingenjör till Arctic Paper Grycksbo AB, Clockwork Bemanning & Rekrytering AB
# CSG söker en Gruppledare till Stockholmsmässan, Commuter Security Group AB
# Ordningsvakt till Securitas, Securitas AB
# Vi söker utbildade ordningsvakter!, Avarn Security AB
# Väktare till Securitas Avesta, Securitas AB
# Väktare till Securitas Ludvika, Securitas AB
# Stationärväktare heltid till Securitas Gävle, Securitas AB
# Ledigt deltidsjobb som Port Officer till GBG Hamn!, Manpower AB
# Brandsäkerhetstekniker för förstahandsbrandskydd i Stockholm, NOHA Sweden AB
# Klienthandläggare till VO Göteborg Syd, Kriminalvården
# Väktare 2025, Örestads Industribevakning AB
# RSNV söker Gruppchef till operativa avdelningen , Räddningstjänsten Skåne Nordväst
# Bygglovhandläggare, Kungälvs kommun
# Gävle tingsrätt söker ordningsvakt (vikariat), Sveriges Domstolar
# 3 simlärare sökes, Malmö kommun
# Parkeringsvakt sökes till Södra Stockholm, Smart Parkering Sverige AB
# Avarn söker platschef till stationärt objekt, Avarn Security AB
# IAM/IGA-konsult till Knowit, Academic Work Sweden AB
# Kriminalvårdare med serviceuppdrag till frivården Stockholm stad, Kriminalvården
# Informations- och säkerhetssamordnare, FALKÖPINGS KOMMUN
# Beredskapssamordnare, Ljungby kommun
# Kommunpoliser till Stockholm City, Polismyndigheten
# Jourutredningsbefäl till utredningsjouren, Polisområde Stockholm Syd, Polismyndigheten
# Väktare sökes i stockholm, Aura Personal AB
# Utvecklingsledare Trygghet och säkerhet, Skara kommun
# Behovsanställd parkeringsvakt sökes till Kristianstad, Smart Parkering Sverige AB
# CSG söker biljett kontrollanter till Eskilstuna, Commuter Security Group AB

# %%
search_params = {
    'occupation-field': list(occupation_fields),
    'limit': 100
}
json_response = _get_ads(search_params)
json_response
# Out:
# {'total': {'value': 6696},
#  'positions': 11090,
#  'query_time_in_millis': 11,
#  'result_time_in_millis': 295,
#  'stats': [],
#  'freetext_concepts': {},
#  'hits': [{'relevance': 1.0,
#    'id': '29948781',
#    'external_id': '46-202100-0225-89A80299E2A049948A741AB0A4E99228',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29948781',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2021000225/logotyper/logo.png',
#    'headline': 'Vakthavande befäl till VO Häktet Helsingborg (vikariat)',
#    'application_deadline': '2025-10-03T23:59:59',
#    'number_of_vacancies': 3,
#    'description': {'text': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nVO häktet Helsingborg består idag av restriktionshäktet Helsingborg och gemensamhetshäktet Berga. På häktet finns olika avdelningar som restriktionsavdelning, ungdomsavdelning och en kvinnoavdelning. Häktet Berga tar emot klienter utan restriktioner.\n\nLäs mer om vår verksamhet på hemsidan.\nHäktet Helsingborg: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/helsingborg/#verksamhet\n\nHäktet Berga: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/haktet-berga/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nSom vakthavande befäl ska du i samråd med kriminalvårdsinspektörerna operativt leda och fördela dagliga arbetsuppgifter. Vakthavande befäl företräder arbetsgivaren och är en garanti för att chefslinjen bibehålls hela vägen ut till samtlig personal. För att lösa arbetsuppgifterna krävs ett bra och nära samarbete med samtliga befattningar inom verksamhetsområdet. Vakthavande befäl finns i tjänst dygnet runt och är utanför kontorstid den lokalt högsta operativa beslutsfattaren. Arbetet är varierande och håller många gånger ett högt tempo. Som vakthavande befäl på häktet Helsingborg förankrar du tagna beslut, kommunicerar rakt och tydligt och bidrar till en trygg och effektiv arbetsmiljö. I rollen ingår även att stötta och leda personal på ett positivt och utvecklande sätt.\n\nNågra av de arbetsuppgifter befattningen innefattar är att följa upp det dagliga säkerhetsarbetet och dess rutiner för att bibehålla en hög dynamisk säkerhetsprofil samt vidta åtgärder vid behov. Vakthavande befäl arbetar också löpande med att bedöma behovet av bemanning och ansvarar för personalrangeringen utanför kontorstid. Vakthavande befäl har också ett särskilt operativt ansvar vid incidenter.\n\r\n\r\nKVALIFIKATIONER\nVi söker dig som är strukturerad och stabil, men samtidigt har förmågan att anpassa dig till ändrade omständigheter. Du har en mycket god samarbetsförmåga och relaterar till människor på ett lyhört och smidigt sätt. I ditt yrkesutövande uppvisar du ett gott omdöme och löser konflikter på ett konstruktivt sätt. Du har förmåga att överblicka och se verksamheten utifrån ett helhetsperspektiv.\n\nI rollen som vakthavande befäl uppträder du professionellt i samarbetet med interna och externa myndighetskontakter.\n\nFör oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Personliga egenskaper som vi kommer att värdesätta är förmågan att arbeta på ett metodiskt och rationellt sätt med bibehållet säkerhetstänk under stress eller hög arbetsbelastning. Som vakthavande befäl har du en viktig roll i verksamheten och mycket stor vikt kommer att läggas vid personlig lämplighet.\n\nVi söker dig som har:\n• Fullständig gymnasiekompetens eller annan utbildning i kombination med arbetslivserfarenhet arbetsgivaren bedömer relevant\n• Kriminalvårdens interna vakthavande befälsutbildning\n• God administrativ förmåga och vana att arbeta i Kriminalvårdens administrativa program \n• Goda kunskaper i svenska i såväl tal som skrift\n• B-körkort\n\nDet är meriterande om du har:\n• Kunskap inom relevanta områden, exempelvis beteendevetenskap, kriminologi, psykiatri, juridik och konflikthantering\n• Förståelse för rättsprocesser samt kunskap inom hanteringen av domar\n• Erfarenhet av att arbeta som vakthavande befäl inom Kriminalvården\n\n ...
#     'text_formatted': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nVO häktet Helsingborg består idag av restriktionshäktet Helsingborg och gemensamhetshäktet Berga. På häktet finns olika avdelningar som restriktionsavdelning, ungdomsavdelning och en kvinnoavdelning. Häktet Berga tar emot klienter utan restriktioner.\n\nLäs mer om vår verksamhet på hemsidan.\nHäktet Helsingborg: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/helsingborg/#verksamhet\n\nHäktet Berga: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/haktet-berga/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nSom vakthavande befäl ska du i samråd med kriminalvårdsinspektörerna operativt leda och fördela dagliga arbetsuppgifter. Vakthavande befäl företräder arbetsgivaren och är en garanti för att chefslinjen bibehålls hela vägen ut till samtlig personal. För att lösa arbetsuppgifterna krävs ett bra och nära samarbete med samtliga befattningar inom verksamhetsområdet. Vakthavande befäl finns i tjänst dygnet runt och är utanför kontorstid den lokalt högsta operativa beslutsfattaren. Arbetet är varierande och håller många gånger ett högt tempo. Som vakthavande befäl på häktet Helsingborg förankrar du tagna beslut, kommunicerar rakt och tydligt och bidrar till en trygg och effektiv arbetsmiljö. I rollen ingår även att stötta och leda personal på ett positivt och utvecklande sätt.\n\nNågra av de arbetsuppgifter befattningen innefattar är att följa upp det dagliga säkerhetsarbetet och dess rutiner för att bibehålla en hög dynamisk säkerhetsprofil samt vidta åtgärder vid behov. Vakthavande befäl arbetar också löpande med att bedöma behovet av bemanning och ansvarar för personalrangeringen utanför kontorstid. Vakthavande befäl har också ett särskilt operativt ansvar vid incidenter.\n\r\n\r\nKVALIFIKATIONER\nVi söker dig som är strukturerad och stabil, men samtidigt har förmågan att anpassa dig till ändrade omständigheter. Du har en mycket god samarbetsförmåga och relaterar till människor på ett lyhört och smidigt sätt. I ditt yrkesutövande uppvisar du ett gott omdöme och löser konflikter på ett konstruktivt sätt. Du har förmåga att överblicka och se verksamheten utifrån ett helhetsperspektiv.\n\nI rollen som vakthavande befäl uppträder du professionellt i samarbetet med interna och externa myndighetskontakter.\n\nFör oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Personliga egenskaper som vi kommer att värdesätta är förmågan att arbeta på ett metodiskt och rationellt sätt med bibehållet säkerhetstänk under stress eller hög arbetsbelastning. Som vakthavande befäl har du en viktig roll i verksamheten och mycket stor vikt kommer att läggas vid personlig lämplighet.\n\nVi söker dig som har:\n• Fullständig gymnasiekompetens eller annan utbildning i kombination med arbetslivserfarenhet arbetsgivaren bedömer relevant\n• Kriminalvårdens interna vakthavande befälsutbildning\n• God administrativ förmåga och vana att arbeta i Kriminalvårdens administrativa program \n• Goda kunskaper i svenska i såväl tal som skrift\n• B-körkort\n\nDet är meriterande om du har:\n• Kunskap inom relevanta områden, exempelvis beteendevetenskap, kriminologi, psykiatri, juridik och konflikthantering\n• Förståelse för rättsprocesser samt kunskap inom hanteringen av domar\n• Erfarenhet av att arbeta som vakthavande befäl inom Kriminalvården\n\n\r\n\ ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid.  Schema. Mån-Sön schema. Kvällar och nätter förekommer\r\nTidsbegränsad anställning, tillträde: Enligt överenskommelse, upphör: 2026-05-03  .'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Månadslön Individuell lönesättning tillämpas',
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2021000225',
#     'name': 'Kriminalvården',
#     'workplace': 'Kriminalvården, Häktet Helsingborg '},
#    'application_details': {'information': None,
#     'reference': 'C274166',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=89a80299-e2a0-4994-8a74-1ab0a4e99228&publishCode=AMS&TK=1b022ea5-fcda-4f9f-891b-d66cd785f638',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'NoHX_doS_a8J',
#     'label': 'Kriminalvårdare',
#     'legacy_ams_taxonomy_id': '2503'},
#    'occupation_group': {'concept_id': 'hgAg_gLr_YGg',
#     'label': 'Kriminalvårdare',
#     'legacy_ams_taxonomy_id': '5412'},
#    'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#     'label': 'Säkerhet och bevakning',
#     'legacy_ams_taxonomy_id': '17'},
#    'workplace_address': {'municipality': 'Helsingborg',
#     'municipality_code': '1283',
#     'municipality_concept_id': 'qj3q_oXH_MGR',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [12.694512, 56.046467]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Ellen Rosvall Norén',
#      'email': 'Ellen.Rosvallnoren@kriminalvarden.se',
#      'telephone': None,
#      'contact_type': 'Rekryteringsspecialist'}],
#    'publication_date': '2025-09-15T00:00:00',
#    'last_publication_date': '2025-10-03T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1756278016935},
#   {'relevance': 1.0,
#    'id': '29927385',
#    'external_id': '46-202100-0225-95DA323575324E02A71A774D074CC397',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29927385',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2021000225/logotyper/logo.png',
#    'headline': 'Säkerhetshandläggare med ansvar för brand till anstalten Kumla',
#    'application_deadline': '2025-10-05T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nLäs mer om anstalten Kumlas verksamhet på vår hemsida: \nhttps://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/anstalt/kumla/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nVi söker en säkerhetshandläggare till stöd för verksamheten vid anstalten Kumla. Anstaltens säkerhetsarbete är under utveckling mot bakgrund av kapacitetsökning och säkerhetsläget nationellt, samt utifrån övriga behov som myndigheten har. Säkerhetsfrågor fördelas mellan säkerhetshandläggarna utifrån vilket ansvarsområde man har.\n\nSäkerhetshandläggarna har en central roll i verksamhetens säkerhetsorganisation på anstalten och utgör ett stöd till ledningen i säkerhetsfrågor. Säkerhetshandläggarna ansvarar för att följa, följa upp och analysera det vardagliga säkerhetsarbetet inkluderat de incidenter som inträffar. I befattningen ingår kvalitetssäkring av anstaltens brandskyddsarbete samt revidering av lokala rutiner, regelverk och samverkan i regionens brandskyddsarbete. Du samarbetar med flertalet funktioner inom myndigheten men även med andra aktörer som exempelvis räddningstjänsten.\n\nAnstalten söker nu en säkerhetshandläggare, med ansvar för brandskydd. I rollen kommer du ha ansvar för anstaltens brandskyddsarbete i samarbete med brandskyddsansvarig och ansvara för utbildning och stöttning av de lokala brandombuden. Du kommer i samarbete med brandskyddsansvarig ansvara för utbildning och utveckling av årsplaner för det särskilda brandansvaret på anstalten. Tjänsten är ny vilket innebär att du kommer vara med och sätta ramarna för rollen, vilket ställer höga krav på dig som person.\r\n\r\nKVALIFIKATIONER\nSom person är du prestationsorienterad, självgående och uthållig. Du är analytisk och har god förmåga att kommunicera såväl i tal som i skrift. Att vara relationsskapande och ha god samarbetsförmåga är nycklar i rollen då du kommer behöva skapa nya kontakter för att utveckla brandskyddsarbetet på anstalten. Det är viktigt att du är pedagogisk då du kommer ha ansvar för att utbilda personal inom brandskydd. För oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Vi lägger stor vikt vid personlig lämplighet.\n\nKrav: \n• Fullständig gymnasiekompetens i form av slutbetyg eller gymnasieexamen\n• Förmåga att uttrycka sig väl i tal och skrift på svenska \n• Tidigare yrkeserfarenhet av att jobbat med brandskyddsfrågor \n\nMeriterande: \n• Arbetslivserfarenhet inom kriminalvården \n• Erfarenhet av kvalificerat säkerhetsarbete \n• Kunskap och erfarenhet inom områdena ISAP, informationssäkerhet och säkerhetshandboken \n• Goda kunskaper om gällande lagstiftning och föreskrifter \n• Utbildad övningsledare eller har erfarenhet av att leda teoretiska samt praktiska utbildningar \r\n\nÖVRIGT\nVi ställer höga krav på våra medarbetares säkerhets- och sekretessmedvetande. För att arbeta hos oss behöver du genomgå en säkerhetsprövning i enlighet med säkerhetsskyddslagen. Befattningen är placerad i säkerhetsklass och en säkerhetsprövning innefattande en säkerhetsprövningsintervju med registerkontroll kommer att genomföras innan beslut om anställning fattas. Vid säkerhetsprövningen utreds du som person, din bakgrund och dina relationer ur ett säkerhetsperspektiv. Du behöver vara svensk medborgare, men får gärna ha utländsk bakgrund. I samband med din anställningsintervju får du mer inf ...
#     'text_formatted': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nLäs mer om anstalten Kumlas verksamhet på vår hemsida: \nhttps://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/anstalt/kumla/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nVi söker en säkerhetshandläggare till stöd för verksamheten vid anstalten Kumla. Anstaltens säkerhetsarbete är under utveckling mot bakgrund av kapacitetsökning och säkerhetsläget nationellt, samt utifrån övriga behov som myndigheten har. Säkerhetsfrågor fördelas mellan säkerhetshandläggarna utifrån vilket ansvarsområde man har.\n\nSäkerhetshandläggarna har en central roll i verksamhetens säkerhetsorganisation på anstalten och utgör ett stöd till ledningen i säkerhetsfrågor. Säkerhetshandläggarna ansvarar för att följa, följa upp och analysera det vardagliga säkerhetsarbetet inkluderat de incidenter som inträffar. I befattningen ingår kvalitetssäkring av anstaltens brandskyddsarbete samt revidering av lokala rutiner, regelverk och samverkan i regionens brandskyddsarbete. Du samarbetar med flertalet funktioner inom myndigheten men även med andra aktörer som exempelvis räddningstjänsten.\n\nAnstalten söker nu en säkerhetshandläggare, med ansvar för brandskydd. I rollen kommer du ha ansvar för anstaltens brandskyddsarbete i samarbete med brandskyddsansvarig och ansvara för utbildning och stöttning av de lokala brandombuden. Du kommer i samarbete med brandskyddsansvarig ansvara för utbildning och utveckling av årsplaner för det särskilda brandansvaret på anstalten. Tjänsten är ny vilket innebär att du kommer vara med och sätta ramarna för rollen, vilket ställer höga krav på dig som person.\r\n\r\nKVALIFIKATIONER\nSom person är du prestationsorienterad, självgående och uthållig. Du är analytisk och har god förmåga att kommunicera såväl i tal som i skrift. Att vara relationsskapande och ha god samarbetsförmåga är nycklar i rollen då du kommer behöva skapa nya kontakter för att utveckla brandskyddsarbetet på anstalten. Det är viktigt att du är pedagogisk då du kommer ha ansvar för att utbilda personal inom brandskydd. För oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Vi lägger stor vikt vid personlig lämplighet.\n\nKrav: \n• Fullständig gymnasiekompetens i form av slutbetyg eller gymnasieexamen\n• Förmåga att uttrycka sig väl i tal och skrift på svenska \n• Tidigare yrkeserfarenhet av att jobbat med brandskyddsfrågor \n\nMeriterande: \n• Arbetslivserfarenhet inom kriminalvården \n• Erfarenhet av kvalificerat säkerhetsarbete \n• Kunskap och erfarenhet inom områdena ISAP, informationssäkerhet och säkerhetshandboken \n• Goda kunskaper om gällande lagstiftning och föreskrifter \n• Utbildad övningsledare eller har erfarenhet av att leda teoretiska samt praktiska utbildningar \r\n\nÖVRIGT\nVi ställer höga krav på våra medarbetares säkerhets- och sekretessmedvetande. För att arbeta hos oss behöver du genomgå en säkerhetsprövning i enlighet med säkerhetsskyddslagen. Befattningen är placerad i säkerhetsklass och en säkerhetsprövning innefattande en säkerhetsprövningsintervju med registerkontroll kommer att genomföras innan beslut om anställning fattas. Vid säkerhetsprövningen utreds du som person, din bakgrund och dina relationer ur ett säkerhetsperspektiv. Du behöver vara svensk medborgare, men får gärna ha utländsk bakgrund. I samband med din anställningsintervju får du mer informat ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid.  Dagtid. Måndag-fredag, flextid\r\nTillsvidareanställning, tillträde: Enligt överenskommelse .'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Månadslön Individuell lönesättning tillämpas\n\n',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2021000225',
#     'name': 'Kriminalvården',
#     'workplace': 'Kriminalvården, Anstalten Kumla'},
#    'application_details': {'information': None,
#     'reference': 'C273028',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=95da3235-7532-4e02-a71a-774d074cc397&publishCode=AMS&TK=f6a68578-6a90-4d9e-a415-ae69b3c0054c',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'PLBW_6Py_neC',
#     'label': 'Säkerhetsrådgivare',
#     'legacy_ams_taxonomy_id': '6771'},
#    'occupation_group': {'concept_id': 'nuXg_Wjc_JPd',
#     'label': 'Säkerhetsinspektörer m.fl.',
#     'legacy_ams_taxonomy_id': '3354'},
#    'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#     'label': 'Säkerhet och bevakning',
#     'legacy_ams_taxonomy_id': '17'},
#    'workplace_address': {'municipality': 'Kumla',
#     'municipality_code': '1881',
#     'municipality_concept_id': 'viCA_36P_pQp',
#     'region': 'Örebro län',
#     'region_code': '18',
#     'region_concept_id': 'xTCk_nT5_Zjm',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [15.140105, 59.126537]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Felicia Sundberg',
#      'email': 'felicia.sundberg@kriminalvarden.se',
#      'telephone': '076-215 17 64',
#      'contact_type': 'Rekryteringsspecialist'},
#     {'name': None,
#      'description': 'Martin Lindvall',
#      'email': None,
#      'telephone': '077-22 80 800',
#      'contact_type': 'Kriminalvårdsinspektör'},
#     {'name': None,
#      'description': 'Tilda Lalander',
#      'email': 'tilda.lalander@kriminalvarden.se',
#      'telephone': '073-588 76 89',
#      'contact_type': 'Rekryteringsspecialist '}],
#    'publication_date': '2025-09-15T00:00:00',
#    'last_publication_date': '2025-10-05T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1755674127532},
#   {'relevance': 1.0,
#    'id': '29948755',
#    'external_id': '46-202100-0225-EE8EB013DDB64254A710421C52247301',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29948755',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2021000225/logotyper/logo.png',
#    'headline': 'Vakthavande befäl till VO Häktet Helsingborg',
#    'application_deadline': '2025-10-03T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nVO häktet Helsingborg består idag av restriktionshäktet Helsingborg och gemensamhetshäktet Berga. På häktet finns olika avdelningar som restriktionsavdelning, ungdomsavdelning och en kvinnoavdelning. Häktet Berga tar emot klienter utan restriktioner.\n\nLäs mer om vår verksamhet på hemsidan.\nHäktet Helsingborg: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/helsingborg/#verksamhet\n\nHäktet Berga: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/haktet-berga/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nSom vakthavande befäl ska du i samråd med kriminalvårdsinspektörerna operativt leda och fördela dagliga arbetsuppgifter. Vakthavande befäl företräder arbetsgivaren och är en garanti för att chefslinjen bibehålls hela vägen ut till samtlig personal. För att lösa arbetsuppgifterna krävs ett bra och nära samarbete med samtliga befattningar inom verksamhetsområdet. Vakthavande befäl finns i tjänst dygnet runt och är utanför kontorstid den lokalt högsta operativa beslutsfattaren. Arbetet är varierande och håller många gånger ett högt tempo.\nSom vakthavande befäl på häktet Helsingborg förankrar du tagna beslut, kommunicerar rakt och tydligt och bidrar till en trygg och effektiv arbetsmiljö. I rollen ingår även att stötta och leda personal på ett positivt och utvecklande sätt.\n\nNågra av de arbetsuppgifter befattningen innefattar är att följa upp det dagliga säkerhetsarbetet och dess rutiner för att bibehålla en hög dynamisk säkerhetsprofil samt vidta åtgärder vid behov. \nVakthavande befäl arbetar också löpande med att bedöma behovet av bemanning och ansvarar för personalrangeringen utanför kontorstid. Vakthavande befäl har ett särskilt operativt ansvar vid incidenter\n\r\n\r\nKVALIFIKATIONER\nVi söker dig som är strukturerad och stabil, men samtidigt har förmågan att anpassa dig till ändrade omständigheter. Du har en mycket god samarbetsförmåga och relaterar till människor på ett lyhört och smidigt sätt. I ditt yrkesutövande uppvisar du ett gott omdöme och löser konflikter på ett konstruktivt sätt. Du har förmåga att överblicka och se verksamheten utifrån ett helhetsperspektiv. \n\nI rollen som vakthavande befäl uppträder du professionellt i samarbetet med interna och externa myndighetskontakter.\n\nFör oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Personliga egenskaper som vi kommer att värdesätta är förmågan att arbeta på ett metodiskt och rationellt sätt med bibehållet säkerhetstänk under stress eller hög arbetsbelastning. Som vakthavande befäl har du en viktig roll i verksamheten och mycket stor vikt kommer att läggas vid personlig lämplighet.\n\nVi söker dig som har:\n• Fullständig gymnasiekompetens eller annan utbildning i kombination med arbetslivserfarenhet arbetsgivaren bedömer relevant\n• Kriminalvårdens interna vakthavande befälsutbildning \n• God administrativ förmåga och vana att arbeta i Kriminalvårdens administrativa program\n• Goda kunskaper i svenska i såväl tal som skrift\n• B-körkort\n\nDet är meriterande om du har:\n• Kunskap inom relevanta områden, exempelvis beteendevetenskap, kriminologi, psykiatri, juridik och konflikthantering\n• Förståelse för rättsprocesser samt kunskap inom hantering av domar \n• Erfarenhet av att arbeta som vakthavande befäl inom Kriminalvården \n\r\n\ ...
#     'text_formatted': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nVO häktet Helsingborg består idag av restriktionshäktet Helsingborg och gemensamhetshäktet Berga. På häktet finns olika avdelningar som restriktionsavdelning, ungdomsavdelning och en kvinnoavdelning. Häktet Berga tar emot klienter utan restriktioner.\n\nLäs mer om vår verksamhet på hemsidan.\nHäktet Helsingborg: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/helsingborg/#verksamhet\n\nHäktet Berga: https://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/hakte/haktet-berga/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nSom vakthavande befäl ska du i samråd med kriminalvårdsinspektörerna operativt leda och fördela dagliga arbetsuppgifter. Vakthavande befäl företräder arbetsgivaren och är en garanti för att chefslinjen bibehålls hela vägen ut till samtlig personal. För att lösa arbetsuppgifterna krävs ett bra och nära samarbete med samtliga befattningar inom verksamhetsområdet. Vakthavande befäl finns i tjänst dygnet runt och är utanför kontorstid den lokalt högsta operativa beslutsfattaren. Arbetet är varierande och håller många gånger ett högt tempo.\nSom vakthavande befäl på häktet Helsingborg förankrar du tagna beslut, kommunicerar rakt och tydligt och bidrar till en trygg och effektiv arbetsmiljö. I rollen ingår även att stötta och leda personal på ett positivt och utvecklande sätt.\n\nNågra av de arbetsuppgifter befattningen innefattar är att följa upp det dagliga säkerhetsarbetet och dess rutiner för att bibehålla en hög dynamisk säkerhetsprofil samt vidta åtgärder vid behov. \nVakthavande befäl arbetar också löpande med att bedöma behovet av bemanning och ansvarar för personalrangeringen utanför kontorstid. Vakthavande befäl har ett särskilt operativt ansvar vid incidenter\n\r\n\r\nKVALIFIKATIONER\nVi söker dig som är strukturerad och stabil, men samtidigt har förmågan att anpassa dig till ändrade omständigheter. Du har en mycket god samarbetsförmåga och relaterar till människor på ett lyhört och smidigt sätt. I ditt yrkesutövande uppvisar du ett gott omdöme och löser konflikter på ett konstruktivt sätt. Du har förmåga att överblicka och se verksamheten utifrån ett helhetsperspektiv. \n\nI rollen som vakthavande befäl uppträder du professionellt i samarbetet med interna och externa myndighetskontakter.\n\nFör oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Personliga egenskaper som vi kommer att värdesätta är förmågan att arbeta på ett metodiskt och rationellt sätt med bibehållet säkerhetstänk under stress eller hög arbetsbelastning. Som vakthavande befäl har du en viktig roll i verksamheten och mycket stor vikt kommer att läggas vid personlig lämplighet.\n\nVi söker dig som har:\n• Fullständig gymnasiekompetens eller annan utbildning i kombination med arbetslivserfarenhet arbetsgivaren bedömer relevant\n• Kriminalvårdens interna vakthavande befälsutbildning \n• God administrativ förmåga och vana att arbeta i Kriminalvårdens administrativa program\n• Goda kunskaper i svenska i såväl tal som skrift\n• B-körkort\n\nDet är meriterande om du har:\n• Kunskap inom relevanta områden, exempelvis beteendevetenskap, kriminologi, psykiatri, juridik och konflikthantering\n• Förståelse för rättsprocesser samt kunskap inom hantering av domar \n• Erfarenhet av att arbeta som vakthavande befäl inom Kriminalvården \n\r\n\nÖVRI ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid.  Schema. Mån-Sön schema. Kvällar och nätter förekommer\r\nTillsvidareanställning, tillträde: Enligt överenskommelse .'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Månadslön Individuell lönesättning tillämpas',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2021000225',
#     'name': 'Kriminalvården',
#     'workplace': 'Kriminalvården, Häktet Helsingborg '},
#    'application_details': {'information': None,
#     'reference': 'C274148',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=ee8eb013-ddb6-4254-a710-421c52247301&publishCode=AMS&TK=a85ed326-2d72-44ae-928a-53e47fb601bc',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'NoHX_doS_a8J',
#     'label': 'Kriminalvårdare',
#     'legacy_ams_taxonomy_id': '2503'},
#    'occupation_group': {'concept_id': 'hgAg_gLr_YGg',
#     'label': 'Kriminalvårdare',
#     'legacy_ams_taxonomy_id': '5412'},
#    'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#     'label': 'Säkerhet och bevakning',
#     'legacy_ams_taxonomy_id': '17'},
#    'workplace_address': {'municipality': 'Helsingborg',
#     'municipality_code': '1283',
#     'municipality_concept_id': 'qj3q_oXH_MGR',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [12.694512, 56.046467]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Ellen Rosvall Norén',
#      'email': 'Ellen.Rosvallnoren@kriminalvarden.se',
#      'telephone': None,
#      'contact_type': 'Rekryteringsspecialist'}],
#    'publication_date': '2025-09-15T00:00:00',
#    'last_publication_date': '2025-10-03T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1756192225667},
#   {'relevance': 1.0,
#    'id': '30015724',
#    'external_id': '46-202100-0225-D7CE71EFAC6343FF843D50DF7EC5D72B',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30015724',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2021000225/logotyper/logo.png',
#    'headline': 'Handläggare Verkställighets planerare (VSP) Nya Anstalten Lindåsa , Tollarp',
#    'application_deadline': '2025-10-06T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nVerksamhetsområdet (VO) Lindåsa, kommer bli en anstalt strax utanför Tollarp med ca 112 platser för män i säkerhetsklass 3.\nArbetet kommer ledas av en anstaltschef tillsammans med 3 kriminalvårdsinspektörer. På anstalten kommer det att bedrivas ett stort verkställighets och utredningsarbete, samtidigt som det kommer finnas värdefull sysselsättning som exempelvis\nträdgård, kök, lärcentrum, programverksamhet och förpacknings verkstad. Vi kommer även lägga stort fokus på säkerhetsarbete i form av tex visitationer och relations skapande arbete/ dynamiskt säkerhetsarbete.\nI den här annonsen söker vi 1 verkställighets planerare.\nEn 6 månaders provanställning kan komma att tillämpas.\r\n\r\nARBETSUPPGIFTER\nSom handläggare inom verkställighets planering (VSP) ansvarar du, tillsammans med en kollega, för att utreda och kartlägga klienternas risker, behov och mottaglighet för återfallsförebyggande insatser samt att utifrån genomförd utredning upprätta en övergripande planering för klientens verkställighet. I utredningen ingår såväl informationsinhämtning och inläsning som en fysisk intervju med klienten som du därefter analyserar utifrån risk, behovs och mottaglighets faktorer. Samverkan med frivården sker under planeringsstadiet. Du föredrar därefter såväl utredningen som planeringen för klienten, VSP-ansvarig samt annan berörd personal. Vid behov ansvarar du även för att se över och revidera redan befintliga verkställighets planeringar. Som handläggare kommer du att arbeta nära anstaltens administratörer och klient handläggare och vid behov vara behjälplig i deras arbetsuppgifter. Du kommer även fortlöpande att metod handleda och utbilda personal samt följa upp och kvalitetssäkra arbetet med klienternas verkställighets plan.\r\n\r\nKVALIFIKATIONER\nKvalifikationer:\nVi söker dig som är lugn, trygg och stabil samt har god samarbetsförmåga. För att lyckas i rollen krävs god samverkan såväl med externa som interna funktioner. Du ska kunna planera, organisera och prioritera ditt arbete på ett effektivt sätt då arbetsbelastningen varierar utifrån antalet klienter som skrivs in på anstalten. Du tar stort ansvar för såväl dina som din arbetsgrupps arbetsuppgifter. Du ska ha förmåga att kunna hantera stor mängd information och göra väl avvägda bedömningar.\nFör att lyckas i ditt uppdrag är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen och tron på människans vilja och förmåga att utvecklas. Du förväntas med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Du ska även ha en fysisk status som möjliggör att agera fysiskt när situationen så kräver.\nKrav:\n- Fullständig gymnasieexamen.\n- Genomgått Kriminalvårdens grundutbildning.\n- Goda kunskaper i svenska språket i såväl tal som skrift.\n\nDet är meriterande om du har:\n- Kunskap inom relevanta områden, exempelvis beteendevetenskap, kriminologi, psykiatri, juridik och konflikthantering.\n- Arbetslivserfarenhet inom kriminalvård, säkerhetsarbete, social omsorg, psykiatri, vård- och omsorgsarbete.\n- Erfarenhet av att arbeta i Kriminalvårdens klient administrativa system.\n- Genomgått Kriminalvårdens utredar- och/eller planerar utbildning samt har erfarenhet av att genomföra utredningar och planeringar.\n- Goda kunskaper i RBM-B\n- Goda förvaltningsrättsliga kunskaper.\r\n\nÖVRIGT\nFör att bli aktuell för anställning inom Kriminalvården krävs att du motsvarar högt ställda krav gällande lämplighet, omdöme, säkerhets- och sekretessmedvetande och att du följer gällande lagar. Det innebär att du står upp för demokratiska värderingar och den statliga värdegrun ...
#     'text_formatted': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nVerksamhetsområdet (VO) Lindåsa, kommer bli en anstalt strax utanför Tollarp med ca 112 platser för män i säkerhetsklass 3.\nArbetet kommer ledas av en anstaltschef tillsammans med 3 kriminalvårdsinspektörer. På anstalten kommer det att bedrivas ett stort verkställighets och utredningsarbete, samtidigt som det kommer finnas värdefull sysselsättning som exempelvis\nträdgård, kök, lärcentrum, programverksamhet och förpacknings verkstad. Vi kommer även lägga stort fokus på säkerhetsarbete i form av tex visitationer och relations skapande arbete/ dynamiskt säkerhetsarbete.\nI den här annonsen söker vi 1 verkställighets planerare.\nEn 6 månaders provanställning kan komma att tillämpas.\r\n\r\nARBETSUPPGIFTER\nSom handläggare inom verkställighets planering (VSP) ansvarar du, tillsammans med en kollega, för att utreda och kartlägga klienternas risker, behov och mottaglighet för återfallsförebyggande insatser samt att utifrån genomförd utredning upprätta en övergripande planering för klientens verkställighet. I utredningen ingår såväl informationsinhämtning och inläsning som en fysisk intervju med klienten som du därefter analyserar utifrån risk, behovs och mottaglighets faktorer. Samverkan med frivården sker under planeringsstadiet. Du föredrar därefter såväl utredningen som planeringen för klienten, VSP-ansvarig samt annan berörd personal. Vid behov ansvarar du även för att se över och revidera redan befintliga verkställighets planeringar. Som handläggare kommer du att arbeta nära anstaltens administratörer och klient handläggare och vid behov vara behjälplig i deras arbetsuppgifter. Du kommer även fortlöpande att metod handleda och utbilda personal samt följa upp och kvalitetssäkra arbetet med klienternas verkställighets plan.\r\n\r\nKVALIFIKATIONER\nKvalifikationer:\nVi söker dig som är lugn, trygg och stabil samt har god samarbetsförmåga. För att lyckas i rollen krävs god samverkan såväl med externa som interna funktioner. Du ska kunna planera, organisera och prioritera ditt arbete på ett effektivt sätt då arbetsbelastningen varierar utifrån antalet klienter som skrivs in på anstalten. Du tar stort ansvar för såväl dina som din arbetsgrupps arbetsuppgifter. Du ska ha förmåga att kunna hantera stor mängd information och göra väl avvägda bedömningar.\nFör att lyckas i ditt uppdrag är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen och tron på människans vilja och förmåga att utvecklas. Du förväntas med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Du ska även ha en fysisk status som möjliggör att agera fysiskt när situationen så kräver.\nKrav:\n- Fullständig gymnasieexamen.\n- Genomgått Kriminalvårdens grundutbildning.\n- Goda kunskaper i svenska språket i såväl tal som skrift.\n\nDet är meriterande om du har:\n- Kunskap inom relevanta områden, exempelvis beteendevetenskap, kriminologi, psykiatri, juridik och konflikthantering.\n- Arbetslivserfarenhet inom kriminalvård, säkerhetsarbete, social omsorg, psykiatri, vård- och omsorgsarbete.\n- Erfarenhet av att arbeta i Kriminalvårdens klient administrativa system.\n- Genomgått Kriminalvårdens utredar- och/eller planerar utbildning samt har erfarenhet av att genomföra utredningar och planeringar.\n- Goda kunskaper i RBM-B\n- Goda förvaltningsrättsliga kunskaper.\r\n\nÖVRIGT\nFör att bli aktuell för anställning inom Kriminalvården krävs att du motsvarar högt ställda krav gällande lämplighet, omdöme, säkerhets- och sekretessmedvetande och att du följer gällande lagar. Det innebär att du står upp för demokratiska värderingar och den statliga värdegrund som ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid.  Dagtid. Måndag-fredag Flexavtal\r\nTillsvidareanställning, tillträde: 1 Januari 2026 eller enligt överenskommelse.'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Månadslön Kriminalvården tillämpar individuell lönesättning.',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2021000225',
#     'name': 'Kriminalvården',
#     'workplace': 'Kriminalvården, Region Syd'},
#    'application_details': {'information': None,
#     'reference': 'C277438',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=d7ce71ef-ac63-43ff-843d-50df7ec5d72b&publishCode=AMS&TK=6502d21b-2fa9-40b0-92e4-d3b2437cf9a2',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'NoHX_doS_a8J',
#     'label': 'Kriminalvårdare',
#     'legacy_ams_taxonomy_id': '2503'},
#    'occupation_group': {'concept_id': 'hgAg_gLr_YGg',
#     'label': 'Kriminalvårdare',
#     'legacy_ams_taxonomy_id': '5412'},
#    'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#     'label': 'Säkerhet och bevakning',
#     'legacy_ams_taxonomy_id': '17'},
#    'workplace_address': {'municipality': 'Kristianstad',
#     'municipality_code': '1290',
#     'municipality_concept_id': 'vrvW_sr8_1en',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [14.156678, 56.029392]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Anna Fältman',
#      'email': 'anna.faltman@kriminalvarden.se',
#      'telephone': None,
#      'contact_type': 'Rekryteringsspecialist'}],
#    'publication_date': '2025-09-15T00:00:00',
#    'last_publication_date': '2025-10-06T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1757577926677},
#   {'relevance': 1.0,
#    'id': '30018606',
#    'external_id': '46-212000-0480-0929A237CB994E188F26615A89283068',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30018606',
#    'logo_url': None,
#    'headline': 'Brandman RIB Skänninge',
#    'application_deadline': '2025-09-29T23:59:59',
#    'number_of_vacancies': 2,
# ...
#     'text_formatted': 'Smart Parkering Sverige AB har idag hand om parkeringsövervakning, drift och förvaltning av garage och parkeringsanläggningar. Detta gör vi på uppdrag av fastighetsägare, bostadsrättsföreningar och förvaltningsföretag. Vi tillhandahåller smarta skräddarsydda digitala och miljövänliga lösningar samt marknadens kundvänligaste plattform. Vi är verksamma på flera orter runt om i landet med ett huvudkontor i Stockholm.\n\nMed miljö och teknik i fokus skapar vi framtidens parkering!\r\n\r\nSmart Parkering Sverige AB är ett framåtsträvande och innovativt parkeringsbolag som erbjuder moderna parkeringslösningar. Vi tror på att interaktionen mellan människor och teknik kan göra underverk!\n\nTjänsten\n\nVi söker nu fler kollegor till våra uppdrag med utgångspunkt från Kristianstad för att fortsätta utvecklingen av parkeringsbranschen. Arbetet som parkeringsvakt kännetecknas av "frihet under eget ansvar" där man självständigt bevakar våra kunders anläggningar för att främja trafiksäkerheten, öka framkomligheten och förbättra trivseln i boendemiljöer. \n\nArbetet utgår från Kristianstad, men man kan komma att bevaka i andra närliggande städer och kommuner vid behov.\n\nArbetsuppgifter:\n\n• Bevaka parkeringsområden med bil och till fots. \n• Kontrollera att parkeringsregler efterlevs. \n• Säkerställa att korrekt och tydlig skyltning finns inom området. \n• Utfärda kontrollavgifter vid överträdelser. \n• Hjälpa parkörer på plats med parkeringsrelaterade frågor. \n• Hjälpa parkörer på plats med frågor gällande våra digitala tjänster. \n\nFör att vara aktuell för tjänsten ser vi att du kan arbeta flexibla tider och dagar då arbetet kan vara förlagt både dag- och kvällstid. Vidare ser vi att du har lätt för att upprätthålla god ordning och reda, själv kan planera och organisera ditt arbete och har en känsla för kvalitet. Smart Parkering Sverige AB är ett växande bolag vilket innebär att du kommer få vara med på en intressant utvecklingsresa.\n\nKvalifikationer:\n\n• Innehaft B-körkort i minst 2 år \n• Goda kunskaper i svenska och engelska \n\nMeriterande\n\n• Tidigare erfarenhet som parkeringsvakt \n• Tidigare erfarenhet inom bevakning \n\nFör att trivas tror vi att du är:\n\n• Serviceinriktad \n• Självständig och ansvarstagande \n• Lugn och saklig i ditt bemötande \n• Flexibel, arbetet innebär varierande arbetsdagar, arbetstider och mycket utomhusarbete \n\nAnställning\n\nTjänsten är en timanställning/vid behov och arbetstidernas förläggning är på dagtid, kvällstid och natt under årets samtliga dagar. På sikt finns möjligheten att arbeta uppemot heltid.\n\nStart är enligt överenskommelse och inleds med en provanställning på 6 månader. Arbetet börjar med en internutbildning på ca en till två veckor inom de lagar och regler som gäller för parkering och skyltning (tomtmark). I samband med anställning begärs utdrag från polisens belastningsregister. Lön och anställningsvillkor utgår enligt kollektivavtal. \n\nLönen som nyanställd är 158,47 kr per timme. \n\nI övrigt tror vi att du drivs av att göra ett gott arbete och av att vara en god representant för Smart Parkering Sverige AB.\n\nUrval:\n\nUrval sker löpande och tjänsten kan komma att tillsättas innan sista ansökningsdag.\n\nVälkommen med din ansökan!\n\nVid frågor kontakta rekryteringsteamet på rekrytering@smartp.se - ansökningar tas enbart emot via formuläret. \n\nTjänsten kan komma att tillsättas innan sista ansökningsdag.',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': '-\r\n-'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Enligt överenskommelse',
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#     'label': 'Deltid',
#     'legacy_ams_taxonomy_id': '2'},
#    'scope_of_work': {'min': 0, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5590490628',
#     'name': 'Smart Parkering Sverige AB',
#     'workplace': 'Smart Parkering Sverige AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://karriar.smartp.se/jobs/300770-behovsanstalld-parkeringsvakt-sokes-till-kristianstad?ref=platsbanken',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': True,
#    'driving_license': [{'concept_id': 'VTK8_WRx_GcM',
#      'label': 'B',
#      'legacy_ams_taxonomy_id': '3'}],
#    'occupation': {'concept_id': '44uM_XPP_VdK',
#     'label': 'Parkeringsvakt',
#     'legacy_ams_taxonomy_id': '5907'},
#    'occupation_group': {'concept_id': 'ayQ4_G3W_A2w',
#     'label': 'Övrig bevaknings- och säkerhetspersonal',
#     'legacy_ams_taxonomy_id': '5419'},
#    'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#     'label': 'Säkerhet och bevakning',
#     'legacy_ams_taxonomy_id': '17'},
#    'workplace_address': {'municipality': 'Kristianstad',
#     'municipality_code': '1290',
#     'municipality_concept_id': 'vrvW_sr8_1en',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [14.156678, 56.029392]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-09-09T17:06:45',
#    'last_publication_date': '2025-10-23T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1757430405708},
#   {'relevance': 1.0,
#    'id': '30008872',
#    'external_id': '46-556589-4507-354',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/30008872',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/5565894507/logotyper/logo.png',
#    'headline': 'CSG söker biljett kontrollanter till Eskilstuna',
#    'application_deadline': '2025-10-08T23:59:59',
#    'number_of_vacancies': 4,
#    'description': {'text': 'CSG söker väktare/biljettkontrollanter till Eskilstuna.\n\nCSG är ett auktoriserat bevakningsföretag med verksamhet i hela Sverige. Vi är ca 850 medarbetare som jobbar med alla former av bevakningstjänster i syfte att skapa en tryggare och säkrare tillvaro dygnet runt, årets alla dagar!\n\n\xa0\n\nCSG söker väktare/biljettkontrollanter för våra uppdrag i Eskilstuna med omnejd.\n\nNu söker vi nya medarbetare till våra uppdrag. Som väktare och biljettkontrollant kommer du vara en viktig del för kontroll av färdbevis åt Sörmlandstrafiken där din kompetens och kunskap kommer vara avgörande för att lyckas i rollen.\n\nArbetsuppgifterna utgörs i huvudsak av biljetkontroll, men även andra arbetsuppgifter kan förekomma.\n\n\xa0\n\nDina erfarenheter\n\nFör tjänsten krävs det att du:\n\n- Har goda språkkunskaper i svenska och engelska (både i tal och skrift).\n\n- Har en tillräckligt god hälsa samt god fysik för att klara av förekommande arbetsuppgifter.\n\n- Har en psykisk stabilitet och stresstålighet för att klara av förekommande arbetsuppgifter.\n\n- Har fullgjord och godkänd väktarutbildning.\n\n\xa0\n\nVi ser det som meriterande om du är flerspråkig och innehar körkort klass B.\n\n\xa0\n\nVi erbjuder\n\nCSG erbjuder en familjär tillvaro och en dynamisk arbetsplats.\n\nBli en del av ett spännande uppdrag med högt tempo och varierande arbetsuppgifter.\n\n- Lön utgår enligt kollektivavtal mellan Säkerhetsföretagen och Svenska Transportarbetarförbundet.\n - Alla uppdragsutbildningar som krävs tillhandandahålls av oss.\n\n- CSG erbjuder friskvårdsbidrag\n\n- På CSG får du genom vår partner Cappy även en unik möjlighet att erhålla en del av din intjänade lön direkt nästkommande vardag.\n\n\xa0\n\nRekrytering sker löpande så vänta inte med att skicka in din ansökan.\n\nInnan en anställning kan bli aktuell måste du först genomgå en säkerhetsprövning där registerkontroll genomförs samt bli godkänd hos Länsstyrelsen för arbete i ett auktoriserat bevakningsföretag.\n\nHar du några frågor eller funderingar om tjänsten, kontakta gärna driftchef mikaela.hellman@csgab.se\n\nVarmt välkommen med din ansökan via vår hemsida\xa0www.csgab.se/jobb\xa0\n\n\xa0\n\nÄr du redo att utmana dig själv? \n Sök redan idag!',
#     'text_formatted': 'CSG söker väktare/biljettkontrollanter till Eskilstuna.\n\nCSG är ett auktoriserat bevakningsföretag med verksamhet i hela Sverige. Vi är ca 850 medarbetare som jobbar med alla former av bevakningstjänster i syfte att skapa en tryggare och säkrare tillvaro dygnet runt, årets alla dagar!\n\n\xa0\n\nCSG söker väktare/biljettkontrollanter för våra uppdrag i Eskilstuna med omnejd.\n\nNu söker vi nya medarbetare till våra uppdrag. Som väktare och biljettkontrollant kommer du vara en viktig del för kontroll av färdbevis åt Sörmlandstrafiken där din kompetens och kunskap kommer vara avgörande för att lyckas i rollen.\n\nArbetsuppgifterna utgörs i huvudsak av biljetkontroll, men även andra arbetsuppgifter kan förekomma.\n\n\xa0\n\nDina erfarenheter\n\nFör tjänsten krävs det att du:\n\n- Har goda språkkunskaper i svenska och engelska (både i tal och skrift).\n\n- Har en tillräckligt god hälsa samt god fysik för att klara av förekommande arbetsuppgifter.\n\n- Har en psykisk stabilitet och stresstålighet för att klara av förekommande arbetsuppgifter.\n\n- Har fullgjord och godkänd väktarutbildning.\n\n\xa0\n\nVi ser det som meriterande om du är flerspråkig och innehar körkort klass B.\n\n\xa0\n\nVi erbjuder\n\nCSG erbjuder en familjär tillvaro och en dynamisk arbetsplats.\n\nBli en del av ett spännande uppdrag med högt tempo och varierande arbetsuppgifter.\n\n- Lön utgår enligt kollektivavtal mellan Säkerhetsföretagen och Svenska Transportarbetarförbundet.\n - Alla uppdragsutbildningar som krävs tillhandandahålls av oss.\n\n- CSG erbjuder friskvårdsbidrag\n\n- På CSG får du genom vår partner Cappy även en unik möjlighet att erhålla en del av din intjänade lön direkt nästkommande vardag.\n\n\xa0\n\nRekrytering sker löpande så vänta inte med att skicka in din ansökan.\n\nInnan en anställning kan bli aktuell måste du först genomgå en säkerhetsprövning där registerkontroll genomförs samt bli godkänd hos Länsstyrelsen för arbete i ett auktoriserat bevakningsföretag.\n\nHar du några frågor eller funderingar om tjänsten, kontakta gärna driftchef mikaela.hellman@csgab.se\n\nVarmt välkommen med din ansökan via vår hemsida\xa0www.csgab.se/jobb\xa0\n\n\xa0\n\nÄr du redo att utmana dig själv? \n Sök redan idag!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Vi tillämpar provanställning 6 månader, därefter fast anställning.\r\nDagtid, kväll och helg förekommer efter fastlagt schema. Vi söker både heltidsanställda och behov'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Lön enligt kollektivavtal\r\nSe annons',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5565894507',
#     'name': 'Commuter Security Group AB',
#     'workplace': 'Commuter Security Group'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://csgab.se/jobb/ansok/?rmpage=apply&rmjob=354&ref=arbetsformedlingen.se%2Fplatsbanken%2F&utm_medium=talentech_publishing&utm_source=platsbanken',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'mobn_aTk_jS6',
#     'label': 'Väktare',
#     'legacy_ams_taxonomy_id': '5906'},
#    'occupation_group': {'concept_id': 'iqZh_3yX_i8n',
#     'label': 'Väktare och ordningsvakter',
#     'legacy_ams_taxonomy_id': '5413'},
#    'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#     'label': 'Säkerhet och bevakning',
#     'legacy_ams_taxonomy_id': '17'},
#    'workplace_address': {'municipality': 'Eskilstuna',
#     'municipality_code': '0484',
#     'municipality_concept_id': 'kMxr_NiX_YrU',
#     'region': 'Södermanlands län',
#     'region_code': '04',
#     'region_concept_id': 's93u_BEb_sx2',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [16.509804, 59.37125]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'mobn_aTk_jS6',
#       'label': 'Väktare',
#       'legacy_ams_taxonomy_id': '5906'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-09-09T16:39:15',
#    'last_publication_date': '2025-10-08T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1757428755677}]}

# %%
json_response["hits"][1]
# Out:
# {'relevance': 1.0,
#  'id': '29927385',
#  'external_id': '46-202100-0225-95DA323575324E02A71A774D074CC397',
#  'original_id': None,
#  'label': '[]',
#  'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29927385',
#  'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2021000225/logotyper/logo.png',
#  'headline': 'Säkerhetshandläggare med ansvar för brand till anstalten Kumla',
#  'application_deadline': '2025-10-05T23:59:59',
#  'number_of_vacancies': 1,
#  'description': {'text': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nLäs mer om anstalten Kumlas verksamhet på vår hemsida: \nhttps://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/anstalt/kumla/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nVi söker en säkerhetshandläggare till stöd för verksamheten vid anstalten Kumla. Anstaltens säkerhetsarbete är under utveckling mot bakgrund av kapacitetsökning och säkerhetsläget nationellt, samt utifrån övriga behov som myndigheten har. Säkerhetsfrågor fördelas mellan säkerhetshandläggarna utifrån vilket ansvarsområde man har.\n\nSäkerhetshandläggarna har en central roll i verksamhetens säkerhetsorganisation på anstalten och utgör ett stöd till ledningen i säkerhetsfrågor. Säkerhetshandläggarna ansvarar för att följa, följa upp och analysera det vardagliga säkerhetsarbetet inkluderat de incidenter som inträffar. I befattningen ingår kvalitetssäkring av anstaltens brandskyddsarbete samt revidering av lokala rutiner, regelverk och samverkan i regionens brandskyddsarbete. Du samarbetar med flertalet funktioner inom myndigheten men även med andra aktörer som exempelvis räddningstjänsten.\n\nAnstalten söker nu en säkerhetshandläggare, med ansvar för brandskydd. I rollen kommer du ha ansvar för anstaltens brandskyddsarbete i samarbete med brandskyddsansvarig och ansvara för utbildning och stöttning av de lokala brandombuden. Du kommer i samarbete med brandskyddsansvarig ansvara för utbildning och utveckling av årsplaner för det särskilda brandansvaret på anstalten. Tjänsten är ny vilket innebär att du kommer vara med och sätta ramarna för rollen, vilket ställer höga krav på dig som person.\r\n\r\nKVALIFIKATIONER\nSom person är du prestationsorienterad, självgående och uthållig. Du är analytisk och har god förmåga att kommunicera såväl i tal som i skrift. Att vara relationsskapande och ha god samarbetsförmåga är nycklar i rollen då du kommer behöva skapa nya kontakter för att utveckla brandskyddsarbetet på anstalten. Det är viktigt att du är pedagogisk då du kommer ha ansvar för att utbilda personal inom brandskydd. För oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Vi lägger stor vikt vid personlig lämplighet.\n\nKrav: \n• Fullständig gymnasiekompetens i form av slutbetyg eller gymnasieexamen\n• Förmåga att uttrycka sig väl i tal och skrift på svenska \n• Tidigare yrkeserfarenhet av att jobbat med brandskyddsfrågor \n\nMeriterande: \n• Arbetslivserfarenhet inom kriminalvården \n• Erfarenhet av kvalificerat säkerhetsarbete \n• Kunskap och erfarenhet inom områdena ISAP, informationssäkerhet och säkerhetshandboken \n• Goda kunskaper om gällande lagstiftning och föreskrifter \n• Utbildad övningsledare eller har erfarenhet av att leda teoretiska samt praktiska utbildningar \r\n\nÖVRIGT\nVi ställer höga krav på våra medarbetares säkerhets- och sekretessmedvetande. För att arbeta hos oss behöver du genomgå en säkerhetsprövning i enlighet med säkerhetsskyddslagen. Befattningen är placerad i säkerhetsklass och en säkerhetsprövning innefattande en säkerhetsprövningsintervju med registerkontroll kommer att genomföras innan beslut om anställning fattas. Vid säkerhetsprövningen utreds du som person, din bakgrund och dina relationer ur ett säkerhetsperspektiv. Du behöver vara svensk medborgare, men får gärna ha utländsk bakgrund. I samband med din anställningsintervju får du mer infor ...
#   'text_formatted': 'Kriminalvården växer – vi bygger nytt, bygger om och bygger till och söker nu fler medarbetare. Vårt viktigaste mål är att minska återfall i brott – att bryta den onda cirkeln. Lyckas vi med det blir samhället tryggare och säkrare för alla. Vi är den myndighet som ansvarar för anstalter, frivård, häkten och klienttransporter.\n\nLäs mer om anstalten Kumlas verksamhet på vår hemsida: \nhttps://www.kriminalvarden.se/kontakt/hitta-och-kontakta/verksamhet/anstalt/kumla/#verksamhet\n\n\r\n\r\nARBETSUPPGIFTER\nVi söker en säkerhetshandläggare till stöd för verksamheten vid anstalten Kumla. Anstaltens säkerhetsarbete är under utveckling mot bakgrund av kapacitetsökning och säkerhetsläget nationellt, samt utifrån övriga behov som myndigheten har. Säkerhetsfrågor fördelas mellan säkerhetshandläggarna utifrån vilket ansvarsområde man har.\n\nSäkerhetshandläggarna har en central roll i verksamhetens säkerhetsorganisation på anstalten och utgör ett stöd till ledningen i säkerhetsfrågor. Säkerhetshandläggarna ansvarar för att följa, följa upp och analysera det vardagliga säkerhetsarbetet inkluderat de incidenter som inträffar. I befattningen ingår kvalitetssäkring av anstaltens brandskyddsarbete samt revidering av lokala rutiner, regelverk och samverkan i regionens brandskyddsarbete. Du samarbetar med flertalet funktioner inom myndigheten men även med andra aktörer som exempelvis räddningstjänsten.\n\nAnstalten söker nu en säkerhetshandläggare, med ansvar för brandskydd. I rollen kommer du ha ansvar för anstaltens brandskyddsarbete i samarbete med brandskyddsansvarig och ansvara för utbildning och stöttning av de lokala brandombuden. Du kommer i samarbete med brandskyddsansvarig ansvara för utbildning och utveckling av årsplaner för det särskilda brandansvaret på anstalten. Tjänsten är ny vilket innebär att du kommer vara med och sätta ramarna för rollen, vilket ställer höga krav på dig som person.\r\n\r\nKVALIFIKATIONER\nSom person är du prestationsorienterad, självgående och uthållig. Du är analytisk och har god förmåga att kommunicera såväl i tal som i skrift. Att vara relationsskapande och ha god samarbetsförmåga är nycklar i rollen då du kommer behöva skapa nya kontakter för att utveckla brandskyddsarbetet på anstalten. Det är viktigt att du är pedagogisk då du kommer ha ansvar för att utbilda personal inom brandskydd. För oss är det viktigt att du delar Kriminalvårdens grundläggande värderingar om en human människosyn, respekt för individen samt tron på människans vilja och förmåga att utvecklas. Du är även medveten om och har förståelse för hur bakgrund, kultur och grupptillhörighet påverkar dig själv och andra. Vidare förväntas du med ditt förhållningssätt bidra till att alla blir likvärdigt bemötta. Vi lägger stor vikt vid personlig lämplighet.\n\nKrav: \n• Fullständig gymnasiekompetens i form av slutbetyg eller gymnasieexamen\n• Förmåga att uttrycka sig väl i tal och skrift på svenska \n• Tidigare yrkeserfarenhet av att jobbat med brandskyddsfrågor \n\nMeriterande: \n• Arbetslivserfarenhet inom kriminalvården \n• Erfarenhet av kvalificerat säkerhetsarbete \n• Kunskap och erfarenhet inom områdena ISAP, informationssäkerhet och säkerhetshandboken \n• Goda kunskaper om gällande lagstiftning och föreskrifter \n• Utbildad övningsledare eller har erfarenhet av att leda teoretiska samt praktiska utbildningar \r\n\nÖVRIGT\nVi ställer höga krav på våra medarbetares säkerhets- och sekretessmedvetande. För att arbeta hos oss behöver du genomgå en säkerhetsprövning i enlighet med säkerhetsskyddslagen. Befattningen är placerad i säkerhetsklass och en säkerhetsprövning innefattande en säkerhetsprövningsintervju med registerkontroll kommer att genomföras innan beslut om anställning fattas. Vid säkerhetsprövningen utreds du som person, din bakgrund och dina relationer ur ett säkerhetsperspektiv. Du behöver vara svensk medborgare, men får gärna ha utländsk bakgrund. I samband med din anställningsintervju får du mer informatio ...
#   'company_information': None,
#   'needs': None,
#   'requirements': None,
#   'conditions': 'Heltid.  Dagtid. Måndag-fredag, flextid\r\nTillsvidareanställning, tillträde: Enligt överenskommelse .'},
#  'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#   'label': 'Vanlig anställning',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#   'label': 'Fast månads- vecko- eller timlön',
#   'legacy_ams_taxonomy_id': '1'},
#  'salary_description': 'Månadslön Individuell lönesättning tillämpas\n\n',
#  'duration': {'concept_id': 'a7uU_j21_mkL',
#   'label': 'Tills vidare',
#   'legacy_ams_taxonomy_id': '1'},
#  'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#   'label': 'Heltid',
#   'legacy_ams_taxonomy_id': '1'},
#  'scope_of_work': {'min': 100, 'max': 100},
#  'access': None,
#  'employer': {'phone_number': None,
#   'email': None,
#   'url': None,
#   'organization_number': '2021000225',
#   'name': 'Kriminalvården',
#   'workplace': 'Kriminalvården, Anstalten Kumla'},
#  'application_details': {'information': None,
#   'reference': 'C273028',
#   'email': None,
#   'via_af': False,
#   'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=95da3235-7532-4e02-a71a-774d074cc397&publishCode=AMS&TK=f6a68578-6a90-4d9e-a415-ae69b3c0054c',
#   'other': None},
#  'experience_required': False,
#  'access_to_own_car': False,
#  'driving_license_required': False,
#  'driving_license': None,
#  'occupation': {'concept_id': 'PLBW_6Py_neC',
#   'label': 'Säkerhetsrådgivare',
#   'legacy_ams_taxonomy_id': '6771'},
#  'occupation_group': {'concept_id': 'nuXg_Wjc_JPd',
#   'label': 'Säkerhetsinspektörer m.fl.',
#   'legacy_ams_taxonomy_id': '3354'},
#  'occupation_field': {'concept_id': 'E7hm_BLq_fqZ',
#   'label': 'Säkerhet och bevakning',
#   'legacy_ams_taxonomy_id': '17'},
#  'workplace_address': {'municipality': 'Kumla',
#   'municipality_code': '1881',
#   'municipality_concept_id': 'viCA_36P_pQp',
#   'region': 'Örebro län',
#   'region_code': '18',
#   'region_concept_id': 'xTCk_nT5_Zjm',
#   'country': 'Sverige',
#   'country_code': '199',
#   'country_concept_id': 'i46j_HmG_v64',
#   'street_address': None,
#   'postcode': None,
#   'city': None,
#   'coordinates': [15.140105, 59.126537]},
#  'must_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'nice_to_have': {'skills': [],
#   'languages': [],
#   'work_experiences': [],
#   'education': [],
#   'education_level': []},
#  'application_contacts': [{'name': None,
#    'description': 'Felicia Sundberg',
#    'email': 'felicia.sundberg@kriminalvarden.se',
#    'telephone': '076-215 17 64',
#    'contact_type': 'Rekryteringsspecialist'},
#   {'name': None,
#    'description': 'Martin Lindvall',
#    'email': None,
#    'telephone': '077-22 80 800',
#    'contact_type': 'Kriminalvårdsinspektör'},
#   {'name': None,
#    'description': 'Tilda Lalander',
#    'email': 'tilda.lalander@kriminalvarden.se',
#    'telephone': '073-588 76 89',
#    'contact_type': 'Rekryteringsspecialist '}],
#  'publication_date': '2025-09-15T00:00:00',
#  'last_publication_date': '2025-10-05T23:59:59',
#  'removed': False,
#  'removed_date': None,
#  'source_type': 'VIA_PLATSBANKEN_DXA',
#  'timestamp': 1755674127532}

# %%
json_response["hits"][1].keys()
# Out:
# dict_keys(['relevance', 'id', 'external_id', 'original_id', 'label', 'webpage_url', 'logo_url', 'headline', 'application_deadline', 'number_of_vacancies', 'description', 'employment_type', 'salary_type', 'salary_description', 'duration', 'working_hours_type', 'scope_of_work', 'access', 'employer', 'application_details', 'experience_required', 'access_to_own_car', 'driving_license_required', 'driving_license', 'occupation', 'occupation_group', 'occupation_field', 'workplace_address', 'must_have', 'nice_to_have', 'application_contacts', 'publication_date', 'last_publication_date', 'removed', 'removed_date', 'source_type', 'timestamp'])

# %%
nice_to_have =json_response["hits"][1]["nice_to_have"]
nice_to_have
# Out:
# {'skills': [],
#  'languages': [],
#  'work_experiences': [],
#  'education': [],
#  'education_level': []}
